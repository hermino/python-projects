# %%
import pandas as pd

# %precision %.2f
pd.options.display.float_format = '{:,.2f}'.format

uri = "https://github.com/guilhermesilveira/enem-2018/blob/master/MICRODADOS_ENEM_2018_SAMPLE_43278.csv?raw=true"
dados = pd.read_csv(uri)
dados.head()
# Out:
#    NU_INSCRICAO  NU_ANO  CO_MUNICIPIO_RESIDENCIA NO_MUNICIPIO_RESIDENCIA  \
# 0  180009327796    2018                  2112209                   Timon
# 1  180012890374    2018                  3557105             Votuporanga
# 2  180008223824    2018                  2506301               Guarabira
# 3  180007859645    2018                  3534807              Ouro Verde
# 4  180013499517    2018                  3523107         Itaquaquecetuba
#
#    CO_UF_RESIDENCIA SG_UF_RESIDENCIA  NU_IDADE TP_SEXO  TP_ESTADO_CIVIL  \
# 0                21               MA     34.00       M             1.00
# 1                35               SP     14.00       M             0.00
# 2                25               PB     20.00       F             0.00
# 3                35               SP     17.00       F             0.00
# 4                35               SP     19.00       M             0.00
#
#    TP_COR_RACA  ...  Q018  Q019 Q020  Q021 Q022  Q023  Q024  Q025  Q026  Q027
# ...

# %%
dados.Q006.value_counts().plot(kind='bar');

# %%
dados.shape
# Out:
# (137844, 137)

# %%
dados.describe()
# Out:
#             NU_INSCRICAO     NU_ANO  CO_MUNICIPIO_RESIDENCIA  \
# count         137,844.00 137,844.00               137,844.00
# mean  180,010,423,553.31   2,018.00             3,118,377.40
# std         1,918,950.00       0.00               994,483.04
# min   180,007,186,686.00   2,018.00             1,100,015.00
# 25%   180,008,761,760.75   2,018.00             2,409,100.00
# 50%   180,010,373,993.50   2,018.00             3,137,700.00
# 75%   180,012,032,768.50   2,018.00             3,550,308.00
# max   180,014,002,596.00   2,018.00             5,300,108.00
#
#        CO_UF_RESIDENCIA   NU_IDADE  TP_ESTADO_CIVIL  TP_COR_RACA  \
# count        137,844.00 137,843.00       132,485.00   137,844.00
# mean              31.03      22.38             0.12         2.12
# std                9.92       7.61             0.38         1.02
# min               11.00      13.00             0.00         0.00
# 25%               24.00      18.00             0.00         1.00
# ...

# %%
colunas_de_notas = ['NU_NOTA_CN',
                    'NU_NOTA_CH',
                    'NU_NOTA_LC',
                    'NU_NOTA_MT',
                    'NU_NOTA_REDACAO',
                    'TP_ESCOLA',
                    'Q006',
                    'TP_COR_RACA',
                    'TP_SEXO',
                    'SG_UF_RESIDENCIA']

dados_notas = dados[colunas_de_notas].dropna()
dados_notas.columns = ['ciencias_naturais',
                       'ciencias_humanas',
                       'linguagem_codigo',
                       'matematica',
                       'redacao',
                       'tipo_escola',
                       'renda_familiar',
                       'raca',
                       'sexo',
                       'estado']
dados_notas.head()
# Out:
#    ciencias_naturais  ciencias_humanas  linguagem_codigo  matematica  redacao  \
# 1             523.10            671.30            661.60      738.00   680.00
# 2             409.20            531.70            389.00      438.10   600.00
# 3             452.30            505.50            448.50      544.90   400.00
# 6             428.50            505.20            521.00      436.80   560.00
# 8             491.80            575.70            524.40      487.60   660.00
#
#    tipo_escola renda_familiar  raca sexo estado
# 1            1              N     1    M     SP
# 2            1              B     2    F     PB
# 3            1              F     2    F     SP
# 6            2              B     3    F     AL
# 8            1              B     2    F     PE

# %%
dados_notas.query("renda_familiar == 'C'").describe()
# Out:
#        ciencias_naturais  ciencias_humanas  linguagem_codigo  matematica  \
# count          24,532.00         24,532.00         24,532.00   24,532.00
# mean              477.44            557.12            515.28      510.50
# std                62.00             74.63             65.83       84.91
# min                 0.00              0.00              0.00        0.00
# 25%               428.80            502.10            469.80      446.40
# 50%               470.00            569.60            518.75      498.00
# 75%               519.20            615.40            563.40      561.20
# max               778.10            801.30            719.10      971.40
#
#         redacao  tipo_escola      raca
# count 24,532.00    24,532.00 24,532.00
# mean     484.53         1.31      2.24
# std      168.45         0.58      0.98
# min        0.00         1.00      0.00
# 25%      360.00         1.00      1.00
# 50%      500.00         1.00      3.00
# ...

# %%
dados_notas.query("renda_familiar == 'O'").describe()
# Out:
#        ciencias_naturais  ciencias_humanas  linguagem_codigo  matematica  \
# count             981.00            981.00            981.00      981.00
# mean              575.83            641.55            599.72      654.82
# std                83.46             64.73             58.77      115.84
# min               378.30            411.70            377.80      373.20
# 25%               515.70            617.80            568.30      567.20
# 50%               579.20            653.00            607.10      678.30
# 75%               636.10            682.30            637.90      737.80
# max               848.10            840.90            771.20      989.90
#
#        redacao  tipo_escola   raca
# count   981.00       981.00 981.00
# mean    683.06         1.80   1.54
# std     172.67         1.30   0.96
# min       0.00         1.00   0.00
# 25%     580.00         1.00   1.00
# 50%     680.00         1.00   1.00
# 75%     820.00         4.00   2.00
# ...

# %%
corr = dados_notas.corr()
corr
# Out:
#                    ciencias_naturais  ciencias_humanas  linguagem_codigo  \
# ciencias_naturais               1.00              0.57              0.60
# ciencias_humanas                0.57              1.00              0.70
# linguagem_codigo                0.60              0.70              1.00
# matematica                      0.58              0.53              0.57
# redacao                         0.51              0.50              0.56
#
#                    matematica  redacao
# ciencias_naturais        0.58     0.51
# ciencias_humanas         0.53     0.50
# linguagem_codigo         0.57     0.56
# matematica               1.00     0.48
# redacao                  0.48     1.00

# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});

# %%
sns.heatmap(corr);

# %%
sns.pairplot(dados_notas)
